# %% [markdown]
# <a href="https://colab.research.google.com/github/ssmubc/Rock_Paper_Scissors_Game_Python/blob/main/Rock_Paper_Scissors_Game_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Rock, Paper, Scissors Game**
# ## Sharon Marfatia Python Project
# #### In this program I have created an update_counts function to keep track of the times a specific input was provided by the player to therefore predict the computer's next move accordingly.
# #### In this game if the player and the computer choose the same value, then the computer gets a point. If the player and computer choose different values from rock, paper, and scissors then the player gets a point.
# #### I have created an update_scores function to keep track of the score. This game will be played for 5 trials.

# %%
import random

count_rock = 0
count_paper = 0
count_scissors = 0

# This function updates the count of the user's input
def update_counts(user_input):
  global count_rock, count_paper, count_scissors
  if user_input == 0:
    count_rock = count_rock + 1
  elif user_input == 1:
    count_paper = count_paper + 1
  elif user_input == 2:
    count_scissors = count_scissors + 1

# This function allows the computer to predict a value based on the user input probability
def predict():
  if count_rock > count_paper and count_rock > count_scissors:
    pred = 0
  elif count_paper > count_rock and count_paper > count_scissors:
    pred = 1
  elif count_scissors > count_paper and count_scissors > count_rock:
    pred = 2
  else:
    pred = random.randint(0, 2)
  return pred
  
player_score = 0
comp_score = 0

# Rock wins over scissors, scissors win over paper and paper wins over rock.
def update_scores(user_input):
  global player_score, comp_score
  pred = predict()
  if user_input == 0:
    if pred == 0:
      print("\nYou played ROCK, computer played ROCK.")
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)
    elif pred == 1:
      print("\nYou played ROCK, computer played PAPER.")
      comp_score += 1
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)
    else:
      print("\nYou played ROCK, computer played SCISSORS.")
      player_score += 1
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)
  if user_input == 1:
    if pred == 1:
      print("\nYou played PAPER, computer played PAPER.")
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)
    elif pred == 0:
      print("\nYou played PAPER, computer played ROCK.")
      player_score += 1
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)
    else:
      print("\nYou played PAPER, computer played SCISSORS.")
      comp_score += 1
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)
  if user_input == 2:
    if pred == 2:
      print("\nYou played SCISSORS, computer played SCISSORS.")
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)
    elif pred == 1:
      print("\nYou played SCISSORS, computer played PAPER.")
      player_score += 1
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)
    else:
      print("\nYou played SCISSORS, computer played ROCK.")
      comp_score += 1
      print("\nComputer Score: ", comp_score, "\nYour Score: ", player_score)

valid_entries = ['0', '1', '2']
player_score = 0
comp_score = 0
while True:
  user_input = input("\nEnter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: ")
  while user_input not in valid_entries:
    print("Invalid Input!")
    user_input = input("\nEnter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: ")
  user_input = int(user_i0
                   nput)
  update_scores(user_input)
  update_counts(user_input)
  if comp_score == 5:
    print("Computer Won!")
    break 
  elif player_score == 5:
    print("You Won!")
    break
# Out:
# Enter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: 0
#
# You played ROCK, computer played PAPER.
#
# Computer Score:  1
# Your Score:  0
#
# Enter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: 2
#
# You played SCISSORS, computer played ROCK.
#
# Computer Score:  2
# Your Score:  0
#
# Enter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: 1
#
# You played PAPER, computer played SCISSORS.
#
# Computer Score:  3
# Your Score:  0
#
# Enter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: 2
#
# You played SCISSORS, computer played SCISSORS.
#
# Computer Score:  3
# Your Score:  0
#
# Enter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: 0
#
# You played ROCK, computer played SCISSORS.
#
# Computer Score:  3
# Your Score:  1
#
# Enter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: 1
#
# You played PAPER, computer played SCISSORS.
#
# Computer Score:  4
# Your Score:  1
#
# Enter 0 for ROCK, 1 for PAPER and 2 for SCISSORS: 2
#
# You played SCISSORS, computer played ROCK.
#
# Computer Score:  5
# ...
